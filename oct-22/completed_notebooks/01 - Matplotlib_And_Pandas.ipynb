# %% [markdown]
# <img style="float: right;" width="120" src="https://s3.eu-west-1.amazonaws.com/neueda.conygre.com/pydata/images/neueda-logo.jpeg">
# <br><br><br>

# %% [markdown]
# # Synopsis
#
# With Python there are a number of options for plotting available, including:
# - using pandas built-in functions
# - using matplotlib functions directly
# - using other libraries e.g. seaborn, plotly

# %% [markdown]
# # Matplotlib
#
# `%matplotlib inline` is a **magic** command.<br>
# It means when plotting matplotlib charts, embed them directly into the notebook

# %% [markdown]
# ### Load libraries and import data

# %%
# load pandas
import pandas as pd

# include %matplotlib inline
# %matplotlib inline

# Create a DataFrame called df_premiums from Insurance Premiums.csv
import pandas as pd
df_premiums = pd.read_csv('https://s3.eu-west-1.amazonaws.com/neueda.conygre.com/pydata/Insurance_Premiums.csv', index_col='Date', parse_dates=True)

# %% [markdown]
# ### A quick plot of two columns, this uses matplotlib through pandas

# %%
# line plot of 'USD (AM)' and 'GBP (AM)' columns
ax = df_premiums[ ['USD (AM)', 'GBP (AM)'] ].plot()

# %% [markdown]
# ### Be more specific, plot a single column in red, add a title

# %%
# some extra parameters - USD (AM) line, color and title
df_premiums['USD (PM)'].plot(kind='line', color='r', title='Insurance Premiums')
# Out:
# <AxesSubplot: title={'center': 'Insurance Premiums'}, xlabel='Date'>

# %% [markdown]
# ### For more fine-grained control we can call matplotlib directly

# %%
import matplotlib.pyplot as plt

# create same plot as above, but this time directly through matplotlib
x = df_premiums.index
y = df_premiums['USD (PM)']

plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Insurance Premiums - Closing Price - USD')

plt.show()

# %% [markdown]
# # Anatomy of a figure
#
#
# <img style="float: left; margin-top: 0" width="300" src="https://neueda.conygre.com/pydata/images/subplot.png">
# <img style="float: centre; margin-top: 0" width="300" src="https://neueda.conygre.com/pydata/images/figure.webp">
# <br>
#
#
# **NOTE**
# - difference between `axes` and `axis`
# - both pronounced the same
# - one is singlular, one is plural
# - both refer to different parts of a figure
# - axes contains mulitple axis
# - here axes contains and x-axis and a y-axis

# %% [markdown]
# ### Change style and plot multiple axes on a single figure
#
# See styles at <a href="https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html">matplotlib styles</a>

# %%
plt.style.use('bmh')

fig = plt.figure(figsize=(14, 6))

# left, bottom, width, height
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.18, 0.6, 0.3, 0.3])

x = df_premiums.index.date
y1 = df_premiums['GBP (AM)']

axes1.plot(x, y1, 'g')
axes2.plot(df_premiums['GBP (AM)']['Aug 2008'], 'b')

plt.xticks(rotation=45)

plt.show()

# %%
# save this figure
fig.savefig('example.png')

# %% [markdown]
# ### Plot a histogram through pandas (uses matplotlib under the hood)

# %%
# 'USD (AM)' as a histogram?
df_premiums['USD (AM)'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### An area chart for 3 columns

# %%
my_plot = df_premiums[ ['USD (PM)', 'EURO (PM)', 'GBP (PM)'] ].plot.area(alpha=0.4)

# %% [markdown]
# ### We can save plots to file

# %%
# save to file
my_plot.get_figure().savefig('out.jpg')

# %% [markdown]
# ### Stacked Bar Chart

# %%
df_premiums[ ['USD (PM)', 'EURO (PM)', 'GBP (PM)'] ].resample(rule='Y').mean().plot.bar(stacked=True)
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ### Histograms

# %%
plt.style.use('bmh')
df_premiums['USD (PM)'].plot.hist(bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ### Scatter Plots

# %%
df_premiums.plot.scatter(x='USD (PM)', y='EURO (PM)')
# Out:
# <AxesSubplot: xlabel='USD (PM)', ylabel='EURO (PM)'>

# %% [markdown]
# You can use c to color based off another column value
# Use cmap to indicate colormap to use.
# For all the colormaps, check out: http://matplotlib.org/users/colormaps.html

# %%
df_premiums.plot.scatter(x='USD (PM)', y='EURO (PM)', c='USD (PM)', cmap='Accent')
# Out:
# <AxesSubplot: xlabel='USD (PM)', ylabel='EURO (PM)'>

# %% [markdown]
# ### BoxPlots

# %%
df_premiums['2017-MAY'].plot.box() # Can also pass a "by=..." argument for groupby
# Out:
# C:\Users\stehayes\AppData\Local\Temp\ipykernel_20856\3787234270.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_premiums['2017-MAY'].plot.box() # Can also pass a "by=..." argument for groupby
# <AxesSubplot: >

# %% [markdown]
# ### Hexagonal Bin Plot
#
# Useful for Bivariate Data, alternative to scatterplot:

# %%
df_premiums.plot.hexbin(x='USD (PM)', y='EURO (PM)', gridsize=25, cmap='Oranges')
# Out:
# <AxesSubplot: xlabel='USD (PM)', ylabel='EURO (PM)'>

# %% [markdown]
# ### Kernel Density Estimation plot (KDE)

# %%
df_premiums[ ['USD (PM)', 'EURO (PM)', 'GBP (PM)'] ].plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ### Styling the display of a DataFrame can also be a very useful visualisation tool

# %%
# highlight max and min in df_premiums.head()
df_premiums.head(10).style.highlight_max(color='green').highlight_min(color='red')
# Out:
# <style type="text/css">
# #T_2c907_row2_col0, #T_2c907_row2_col1, #T_2c907_row2_col2, #T_2c907_row2_col3, #T_2c907_row2_col4, #T_2c907_row2_col5 {
#   background-color: red;
# }
# #T_2c907_row9_col0, #T_2c907_row9_col1, #T_2c907_row9_col2, #T_2c907_row9_col3, #T_2c907_row9_col4, #T_2c907_row9_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_2c907">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c907_level0_col0" class="col_heading level0 col0" >USD (AM)</th>
#       <th id="T_2c907_level0_col1" class="col_heading level0 col1" >USD (PM)</th>
#       <th id="T_2c907_level0_col2" class="col_heading level0 col2" >GBP (AM)</th>
#       <th id="T_2c907_level0_col3" class="col_heading level0 col3" >GBP (PM)</th>
#       <th id="T_2c907_level0_col4" class="col_heading level0 col4" >EURO (AM)</th>
#       <th id="T_2c907_level0_col5" class="col_heading level0 col5" >EURO (PM)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c907_level0_row0" class="row_heading level0 row0" >2000-01-04 00:00:00</th>
#       <td id="T_2c907_row0_col0" class="data row0 col0" >282.050000</td>
#       <td id="T_2c907_row0_col1" class="data row0 col1" >281.500000</td>
#       <td id="T_2c907_row0_col2" class="data row0 col2" >172.166000</td>
#       <td id="T_2c907_row0_col3" class="data row0 col3" >171.929000</td>
#       <td id="T_2c907_row0_col4" class="data row0 col4" >275.305000</td>
#       <td id="T_2c907_row0_col5" class="data row0 col5" >272.402000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row1" class="row_heading level0 row1" >2000-01-05 00:00:00</th>
#       <td id="T_2c907_row1_col0" class="data row1 col0" >282.100000</td>
#       <td id="T_2c907_row1_col1" class="data row1 col1" >280.450000</td>
#       <td id="T_2c907_row1_col2" class="data row1 col2" >171.729000</td>
#       <td id="T_2c907_row1_col3" class="data row1 col3" >170.808000</td>
#       <td id="T_2c907_row1_col4" class="data row1 col4" >272.035000</td>
#       <td id="T_2c907_row1_col5" class="data row1 col5" >270.470000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row2" class="row_heading level0 row2" >2000-01-06 00:00:00</th>
#       <td id="T_2c907_row2_col0" class="data row2 col0" >280.350000</td>
#       <td id="T_2c907_row2_col1" class="data row2 col1" >279.400000</td>
#       <td id="T_2c907_row2_col2" class="data row2 col2" >170.446000</td>
#       <td id="T_2c907_row2_col3" class="data row2 col3" >169.518000</td>
#       <td id="T_2c907_row2_col4" class="data row2 col4" >270.974000</td>
#       <td id="T_2c907_row2_col5" class="data row2 col5" >269.152000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row3" class="row_heading level0 row3" >2000-01-07 00:00:00</th>
#       <td id="T_2c907_row3_col0" class="data row3 col0" >282.000000</td>
#       <td id="T_2c907_row3_col1" class="data row3 col1" >282.100000</td>
#       <td id="T_2c907_row3_col2" class="data row3 col2" >171.324000</td>
#       <td id="T_2c907_row3_col3" class="data row3 col3" >172.065000</td>
#       <td id="T_2c907_row3_col4" class="data row3 col4" >273.840000</td>
#       <td id="T_2c907_row3_col5" class="data row3 col5" >274.017000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row4" class="row_heading level0 row4" >2000-01-10 00:00:00</th>
#       <td id="T_2c907_row4_col0" class="data row4 col0" >281.700000</td>
#       <td id="T_2c907_row4_col1" class="data row4 col1" >281.600000</td>
#       <td id="T_2c907_row4_col2" class="data row4 col2" >172.230000</td>
#       <td id="T_2c907_row4_col3" class="data row4 col3" >171.959000</td>
#       <td id="T_2c907_row4_col4" class="data row4 col4" >275.205000</td>
#       <td id="T_2c907_row4_col5" class="data row4 col5" >274.812000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row5" class="row_heading level0 row5" >2000-01-11 00:00:00</th>
#       <td id="T_2c907_row5_col0" class="data row5 col0" >281.700000</td>
#       <td id="T_2c907_row5_col1" class="data row5 col1" >282.250000</td>
#       <td id="T_2c907_row5_col2" class="data row5 col2" >171.590000</td>
#       <td id="T_2c907_row5_col3" class="data row5 col3" >171.424000</td>
#       <td id="T_2c907_row5_col4" class="data row5 col4" >273.469000</td>
#       <td id="T_2c907_row5_col5" class="data row5 col5" >274.322000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row6" class="row_heading level0 row6" >2000-01-12 00:00:00</th>
#       <td id="T_2c907_row6_col0" class="data row6 col0" >282.250000</td>
#       <td id="T_2c907_row6_col1" class="data row6 col1" >282.250000</td>
#       <td id="T_2c907_row6_col2" class="data row6 col2" >171.445000</td>
#       <td id="T_2c907_row6_col3" class="data row6 col3" >171.372000</td>
#       <td id="T_2c907_row6_col4" class="data row6 col4" >273.313000</td>
#       <td id="T_2c907_row6_col5" class="data row6 col5" >274.269000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row7" class="row_heading level0 row7" >2000-01-13 00:00:00</th>
#       <td id="T_2c907_row7_col0" class="data row7 col0" >282.200000</td>
#       <td id="T_2c907_row7_col1" class="data row7 col1" >282.100000</td>
#       <td id="T_2c907_row7_col2" class="data row7 col2" >171.467000</td>
#       <td id="T_2c907_row7_col3" class="data row7 col3" >171.594000</td>
#       <td id="T_2c907_row7_col4" class="data row7 col4" >273.874000</td>
#       <td id="T_2c907_row7_col5" class="data row7 col5" >274.898000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row8" class="row_heading level0 row8" >2000-01-14 00:00:00</th>
#       <td id="T_2c907_row8_col0" class="data row8 col0" >284.150000</td>
#       <td id="T_2c907_row8_col1" class="data row8 col1" >283.300000</td>
#       <td id="T_2c907_row8_col2" class="data row8 col2" >172.683000</td>
#       <td id="T_2c907_row8_col3" class="data row8 col3" >172.439000</td>
#       <td id="T_2c907_row8_col4" class="data row8 col4" >277.274000</td>
#       <td id="T_2c907_row8_col5" class="data row8 col5" >277.881000</td>
#     </tr>
#     <tr>
#       <th id="T_2c907_level0_row9" class="row_heading level0 row9" >2000-01-17 00:00:00</th>
#       <td id="T_2c907_row9_col0" class="data row9 col0" >284.900000</td>
#       <td id="T_2c907_row9_col1" class="data row9 col1" >285.350000</td>
#       <td id="T_2c907_row9_col2" class="data row9 col2" >174.112000</td>
#       <td id="T_2c907_row9_col3" class="data row9 col3" >174.890000</td>
#       <td id="T_2c907_row9_col4" class="data row9 col4" >281.577000</td>
#       <td id="T_2c907_row9_col5" class="data row9 col5" >282.777000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# set a background gradient
df_premiums.head(10).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_7820e_row0_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_7820e_row0_col1, #T_7820e_row5_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_7820e_row0_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_7820e_row0_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_7820e_row0_col4, #T_7820e_row7_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_7820e_row0_col5, #T_7820e_row1_col3, #T_7820e_row3_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_7820e_row1_col0, #T_7820e_row7_col3 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_7820e_row1_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_7820e_row1_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_7820e_row1_col4 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_7820e_row1_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_7820e_row2_col0, #T_7820e_row2_col1, #T_7820e_row2_col2, #T_7820e_row2_col3, #T_7820e_row2_col4, #T_7820e_row2_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7820e_row3_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_7820e_row3_col1, #T_7820e_row4_col3, #T_7820e_row7_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_7820e_row3_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_7820e_row3_col4, #T_7820e_row6_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_7820e_row3_col5 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_7820e_row4_col0, #T_7820e_row5_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_7820e_row4_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_7820e_row4_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_7820e_row4_col4 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_7820e_row4_col5, #T_7820e_row6_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_7820e_row5_col1, #T_7820e_row6_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_7820e_row5_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_7820e_row5_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_7820e_row5_col5 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_7820e_row6_col3 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_7820e_row6_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_7820e_row6_col5 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_7820e_row7_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_7820e_row7_col4 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_7820e_row7_col5 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_7820e_row8_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_7820e_row8_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_7820e_row8_col2 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_7820e_row8_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_7820e_row8_col4 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_7820e_row8_col5 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_7820e_row9_col0, #T_7820e_row9_col1, #T_7820e_row9_col2, #T_7820e_row9_col3, #T_7820e_row9_col4, #T_7820e_row9_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7820e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7820e_level0_col0" class="col_heading level0 col0" >USD (AM)</th>
#       <th id="T_7820e_level0_col1" class="col_heading level0 col1" >USD (PM)</th>
#       <th id="T_7820e_level0_col2" class="col_heading level0 col2" >GBP (AM)</th>
#       <th id="T_7820e_level0_col3" class="col_heading level0 col3" >GBP (PM)</th>
#       <th id="T_7820e_level0_col4" class="col_heading level0 col4" >EURO (AM)</th>
#       <th id="T_7820e_level0_col5" class="col_heading level0 col5" >EURO (PM)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7820e_level0_row0" class="row_heading level0 row0" >2000-01-04 00:00:00</th>
#       <td id="T_7820e_row0_col0" class="data row0 col0" >282.050000</td>
#       <td id="T_7820e_row0_col1" class="data row0 col1" >281.500000</td>
#       <td id="T_7820e_row0_col2" class="data row0 col2" >172.166000</td>
#       <td id="T_7820e_row0_col3" class="data row0 col3" >171.929000</td>
#       <td id="T_7820e_row0_col4" class="data row0 col4" >275.305000</td>
#       <td id="T_7820e_row0_col5" class="data row0 col5" >272.402000</td>
#     </tr>
#     <tr>
#       <th id="T_7820e_level0_row1" class="row_heading level0 row1" >2000-01-05 00:00:00</th>
#       <td id="T_7820e_row1_col0" class="data row1 col0" >282.100000</td>
#       <td id="T_7820e_row1_col1" class="data row1 col1" >280.450000</td>
#       <td id="T_7820e_row1_col2" class="data row1 col2" >171.729000</td>
#       <td id="T_7820e_row1_col3" class="data row1 col3" >170.808000</td>
#       <td id="T_7820e_row1_col4" class="data row1 col4" >272.035000</td>
#       <td id="T_7820e_row1_col5" class="data row1 col5" >270.470000</td>
#     </tr>
#     <tr>
#       <th id="T_7820e_level0_row2" class="row_heading level0 row2" >2000-01-06 00:00:00</th>
#       <td id="T_7820e_row2_col0" class="data row2 col0" >280.350000</td>
#       <td id="T_7820e_row2_col1" class="data row2 col1" >279.400000</td>
#       <td id="T_7820e_row2_col2" class="data row2 col2" >170.446000</td>
#       <td id="T_7820e_row2_col3" class="data row2 col3" >169.518000</td>
#       <td id="T_7820e_row2_col4" class="data row2 col4" >270.974000</td>
#       <td id="T_7820e_row2_col5" class="data row2 col5" >269.152000</td>
#     </tr>
#     <tr>
#       <th id="T_7820e_level0_row3" class="row_heading level0 row3" >2000-01-07 00:00:00</th>
#       <td id="T_7820e_row3_col0" class="data row3 col0" >282.000000</td>
#       <td id="T_7820e_row3_col1" class="data row3 col1" >282.100000</td>
#       <td id="T_7820e_row3_col2" class="data row3 col2" >171.324000</td>
#       <td id="T_7820e_row3_col3" class="data row3 col3" >172.065000</td>
#       <td id="T_7820e_row3_col4" class="data row3 col4" >273.840000</td>
#       <td id="T_7820e_row3_col5" class="data row3 col5" >274.017000</td>
#     </tr>
#     <tr>
#       <th id="T_7820e_level0_row4" class="row_heading level0 row4" >2000-01-10 00:00:00</th>
#       <td id="T_7820e_row4_col0" class="data row4 col0" >281.700000</td>
#       <td id="T_7820e_row4_col1" class="data row4 col1" >281.600000</td>
#       <td id="T_7820e_row4_col2" class="data row4 col2" >172.230000</td>
#       <td id="T_7820e_row4_col3" class="data row4 col3" >171.959000</td>
#       <td id="T_7820e_row4_col4" class="data row4 col4" >275.205000</td>
#       <td id="T_7820e_row4_col5" class="data row4 col5" >274.812000</td>
#     </tr>
#     <tr>
#       <th id="T_7820e_level0_row5" class="row_heading level0 row5" >2000-01-11 00:00:00</th>
#       <td id="T_7820e_row5_col0" class="data row5 col0" >281.700000</td>
#       <td id="T_7820e_row5_col1" class="data row5 col1" >282.250000</td>
#       <td id="T_7820e_row5_col2" class="data row5 col2" >171.590000</td>
#       <td id="T_7820e_row5_col3" class="data row5 col3" >171.424000</td>
#       <td id="T_7820e_row5_col4" class="data row5 col4" >273.469000</td>
#       <td id="T_7820e_row5_col5" class="data row5 col5" >274.322000</td>
#     </tr>
#     <tr>
#       <th id="T_7820e_level0_row6" class="row_heading level0 row6" >2000-01-12 00:00:00</th>
#       <td id="T_7820e_row6_col0" class="data row6 col0" >282.250000</td>
#       <td id="T_7820e_row6_col1" class="data row6 col1" >282.250000</td>
#       <td id="T_7820e_row6_col2" class="data row6 col2" >171.445000</td>
#       <td id="T_7820e_row6_col3" class="data row6 col3" >171.372000</td>
#       <td id="T_7820e_row6_col4" class="data row6 col4" >273.313000</td>
#       <td id="T_7820e_row6_col5" class="data row6 col5" >274.269000</td>
#     </tr>
#     <tr>
#       <th id="T_7820e_level0_ro
